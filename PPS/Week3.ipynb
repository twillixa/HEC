# %% [markdown]
# <a href="https://colab.research.google.com/github/twillixa/HEC/blob/main/PPS/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pulp numpy pandas matplotlib
import pandas as pd
import numpy as np
